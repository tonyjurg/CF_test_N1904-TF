# %% [markdown]
# # Install context-fabric

# %%
# !pip install context-fabric
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.4 MB 6.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/12.4 MB 7.3 MB/s eta 0:00:02
#    -------------- ------------------------- 4.5/12.4 MB 7.2 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.4 MB 7.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.4 MB 7.0 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.4 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.4 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.4 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 6.7 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
# ...

# %% [markdown]
# To add MCP support

# %%
# !pip install context-fabric[mcp]
# Out:
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------------- -------- 1.6/2.0 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 6.3 MB/s  0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# ...
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ----------------- ---------------------- 1.6/3.5 MB 6.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.1/3.5 MB 5.8 MB/s eta 0:00:01
#    -------------------------------- ------- 2.9/3.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 4.0 MB/s  0:00:00
# ...
#
#    -- -------------------------------------  1/16 [python-multipart]
#    ----- ----------------------------------  2/16 [python-dotenv]
#    ------- --------------------------------  3/16 [pyjwt]
# ...
